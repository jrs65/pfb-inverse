# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import pfb
import h5py

# %%
ntime = 2**20

# Generate a white noise timestream
ts = np.random.standard_normal(ntime)

# Perform the PFB
spec_pfb = pfb.pfb(ts, 129)

# Perform the inverse
rts = pfb.inverse_pfb(spec_pfb, 4)

# %%
# Save out PFB data
np.save('testpfb.dat', spec_pfb)

# %%
# Invert PFB data with prog

# %%
# %%bash
#
# rm rects.dat
# mpirun -np 4 python pfbdriver.py testpfb.dat.npy 129 rects.dat 4
# Out:
# MPI process 2 of 4.
# MPI process 1 of 4.
# MPI process 3 of 4.

# %%
# Load in recovered data
with h5py.File('rects.dat', 'r') as f:
    rts2 = f['ts'][:]

# %%
rts2.shape
# Out:
# (4093, 256)

# %%
subplot(121)
imshow(np.log10(np.abs(rts2 - ts.reshape(-1, 256)[3:])), aspect='auto')
#colorbar()
subplot(122)
imshow(np.log10(np.abs(rts - ts.reshape(-1, 256))), aspect='auto')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x131c09d40>

# %%
st = 1000
w = 5
plot(np.log10(np.abs(ts.reshape(-1, 256) - rts)[st:(st+w)].ravel()))
